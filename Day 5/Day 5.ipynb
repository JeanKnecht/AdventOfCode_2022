# %%
def toon_bestand(input_path):
    with open(input_path, 'r') as ifp:
        for line in ifp:
            print(line, end = '')

# %%
toon_bestand("input.txt")
# Out:
#     [H]         [H]         [V]
#     [V]         [V] [J]     [F] [F]
#     [S] [L]     [M] [B]     [L] [J]
#     [C] [N] [B] [W] [D]     [D] [M]
# [G] [L] [M] [S] [S] [C]     [T] [V]
# [P] [B] [B] [P] [Q] [S] [L] [H] [B]
# [N] [J] [D] [V] [C] [Q] [Q] [M] [P]
# [R] [T] [T] [R] [G] [W] [F] [W] [L]
#  1   2   3   4   5   6   7   8   9
#
# move 3 from 3 to 7
# move 4 from 1 to 9
# move 5 from 6 to 3
# move 6 from 9 to 8
# move 2 from 9 to 5
# move 4 from 3 to 7
# move 1 from 3 to 6
# move 3 from 5 to 7
# move 1 from 2 to 1
# move 4 from 7 to 8
# move 17 from 8 to 7
# move 1 from 6 to 2
# move 2 from 6 to 7
# move 1 from 8 to 3
# move 2 from 4 to 6
# move 3 from 9 to 6
# move 5 from 6 to 3
# move 5 from 2 to 1
# move 9 from 3 to 4
# move 20 from 7 to 3
# move 7 from 5 to 3
# move 6 from 3 to 5
# move 4 from 1 to 9
# move 4 from 5 to 6
# move 2 from 1 to 8
# move 2 from 7 to 3
# move 3 from 6 to 3
# move 2 from 5 to 8
# move 2 from 9 to 3
# move 1 from 9 to 6
# move 2 from 2 to 4
# ...
